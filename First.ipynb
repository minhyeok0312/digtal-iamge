# %% [markdown]
# Python version 확인

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/image12.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=620x810>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
print(img.shape)
# Out:
# (810, 620, 3)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
