# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/images/girl.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imshow(gimg, cmap='gray')
# Out:
# (256, 256)

# %%
gPlus = np.zeros((gimg.shape[0], gimg.shape[1]), dtype = np.ubyte)

# %%
val = 100

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    plusVal = gimg[h,w] + val
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

plt.imshow(gPlus, cmap = 'gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/images/aero2.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f60adc9bb5da> in <cell line: 1>()
# ----> 1 img = cv2.imread('/content/drive/My Drive/ColabIP/images/aero2.bmp')
#       2 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3
#       4 gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#       5 print(gimg1.shape)
#
# NameError: name 'cv2' is not defined

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/images/lena256.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bddfb58f7b16> in <cell line: 1>()
# ----> 1 img = cv2.imread('/content/gdrive/My Drive/ColabIP/images/lena256.jpg')
#       2 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3
#       4 gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#       5 print(gimg1.shape)
#
# NameError: name 'cv2' is not defined

# %%
weight = 0.2

for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    plusVal = np.int32(gimg1[h,w])*weight + np.int32(gimg2[h,w])*(1-weight)
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

cv2_imshow(gPlus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1713348dff6f> in <cell line: 3>()
#       1 weight = 0.2
#       2
# ----> 3 for h in range(gimg1.shape[0]):
#       4   for w in range(gimg1.shape[1]):
#       5     plusVal = np.int32(gimg1[h,w])*weight + np.int32(gimg2[h,w])*(1-weight)
#
# NameError: name 'gimg1' is not defined
